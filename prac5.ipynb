# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing

# %%
data = pd.read_csv('/content/sample_data/Folds5x2_pp.csv')

# %%
data
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
data.isnull()
# Out:
#          AT      V     AP     RH     PE
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 9563  False  False  False  False  False
# 9564  False  False  False  False  False
# 9565  False  False  False  False  False
# 9566  False  False  False  False  False
# 9567  False  False  False  False  False
#
# [9568 rows x 5 columns]

# %%
data.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
X = data.drop(['PE'],axis=1).values
Y = data['PE'].values

# %%
print(X)
print(Y)
# Out:
# [[  14.96   41.76 1024.07   73.17]
#  [  25.18   62.96 1020.04   59.08]
#  [   5.11   39.4  1012.16   92.14]
#  ...
#  [  31.32   74.33 1012.92   36.48]
#  [  24.48   69.45 1013.86   62.39]
#  [  21.6    62.52 1017.23   67.87]]
# [463.26 444.37 488.56 ... 429.57 435.74 453.28]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size =0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()

# %%
ml.fit(X,Y)
Y_pred = ml.predict(X_test)
print(Y_pred)
ml.predict([[14.96,41.76,1024.07,73.17]])
# Out:
# [431.45962337 458.54724768 462.73834845 ... 432.44438103 436.24760394
#  438.97411325]
# array([467.26978996])

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,Y_pred)
# Out:
# 0.9304532078923575

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,8))
plt.scatter(Y_test,Y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Multiple lineat regression model")
# Out:
# Text(0.5, 1.0, 'Multiple lineat regression model')
